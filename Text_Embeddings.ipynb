# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitnariya8/Text_Embeddings/blob/main/Text_Embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.3 MB/s eta 0:00:00
# ...

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.9 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %%
import os
os.environ['OPENAI_API_KEY']='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'

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
our_query = "namaste India"

# %%
embeddings = OpenAIEmbeddings()

# %%
# !pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 20.5 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# ...

# %%
text_embeddings = embeddings.embed_query(our_query)

# %%
print(text_embeddings)
# Out:
# [-0.0019920183620287307, -0.020433304157758778, -0.012537132535324074, -0.002712674815185658, -0.02389768432273159, 0.012190694518826792, -0.02517885072968443, 0.002242041910659381, -0.013543763682782397, -0.009530312998820548, 0.0134783988100379, -0.01975350203063566, -0.0026799919131521377, 0.006392761388521669, 0.007536660165727251, -0.0038925247380619857, 0.038095104183539306, -0.028185670266187957, 0.035009844937097294, 0.015949220802101288, 0.003797744741259921, 0.021662178666516024, 0.025714849205447112, 0.02414607363312831, -0.013622202461398338, -0.0019952866056659555, 0.01381829987359946, -0.024969681274256954, -0.0004034286697575531, -0.015347856522271565, -0.0076281719188920905, -0.008628266579075965, -0.016681314827420003, -0.006085542761332358, 0.0032421365708432542, -0.020302572549624698, -0.01947896490849605, -0.0032829901983851546, 0.01452424888114292, -0.003595111074614985, 0.016380633618827686, -0.013922884601313199, 0.0004146633882277462, 0.004088621917432472, -0.
# ...

# %%
import pandas as pd
df = pd.read_excel('Book1.xlsx')
print(df)
# Out:
#     Words
# 0  School
# 1  Banana
# 2     Car

# %%
df['embeddings'] = df['Words'].apply(lambda x:embeddings.embed_query(x))
df.to_csv("New_Embeddings.csv")

# %%
print(df)
# Out:
#     Words                                         embeddings
# 0  School  [0.005531371094329331, 0.009264198113213265, -...
# 1  Banana  [-0.012999765903696864, -0.01998321619391984, ...
# 2     Car  [-0.004958966229655546, -0.012322071811467243,...

# %%
text="Mango"
text_embeddings = embeddings.embed_query(text)
print(f"mango's Embeddings are {text_embeddings}")
# Out:
# mango's Embeddings are [-0.0034055178024402486, -0.019832508079084002, 0.010472126941037743, -0.016190586154939356, 0.00631905655247528, 0.008516989408102721, -0.025122882089670923, -0.014197111660624236, 0.0011077517098275833, -0.03307121898826951, -0.0011668530894996386, 0.003782488764672818, 0.0019183990702938399, 0.016842297734595148, -0.021621524677748073, 0.004792004222854953, 0.03268786055033911, -0.008191132686952277, 0.009385939422740509, -0.01575611114762046, -0.01596056997459406, 0.0027809598630040206, 0.0014703466607885716, -0.012401707120601064, 0.0045587936061688315, 0.009552062219656557, 0.024483948255378432, -0.013660407239818545, 0.011577482940025025, 0.0029918080283205424, 0.04779225825565868, -0.015027725645204474, -0.0043511398771931345, -0.0099226438435462, -0.017596240590382835, 0.004654633681312705, -0.010325171693489196, -0.006373365695559505, -0.006251968267043931, -0.018324624230153727, 0.014452685194341232, -0.008325309257814974, -0.015641102126125263, -0.0
# ...

# %%
from openai.embeddings_utils import cosine_similarity

df["Similarity_Score"] = df['embeddings'].apply(lambda x:cosine_similarity(x,text_embeddings))

df
# Out:
#     Words                                         embeddings  Similarity_Score
# 0  School  [0.005531371094329331, 0.009264198113213265, -...          0.781616
# 1  Banana  [-0.012999765903696864, -0.01998321619391984, ...          0.898764
# 2     Car  [-0.004958966229655546, -0.012322071811467243,...          0.780220

# %%
df.sort_values("Similarity_Score",ascending=False)
# Out:
#     Words                                         embeddings  Similarity_Score
# 1  Banana  [-0.012999765903696864, -0.01998321619391984, ...          0.898764
# 0  School  [0.005531371094329331, 0.009264198113213265, -...          0.781616
# 2     Car  [-0.004958966229655546, -0.012322071811467243,...          0.780220
